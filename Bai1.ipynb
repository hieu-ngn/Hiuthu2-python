# %%
first_name = input("First name: ")
last_name = input("Last name: ")
print(f"Hello, {first_name} {last_name}!")
# Out:
# Hello, Hieu Nguyen!

# %%
price=int(input("Price:"))
tax_rate=int(input("Tax rate:"))
print(f" {price * (1 + tax_rate / 100)}")
# Out:
#  220.00000000000003
